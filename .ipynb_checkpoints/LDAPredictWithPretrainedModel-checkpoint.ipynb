# %% [markdown]
# # Topic Modeling with Latent Dirichlet Allocation in Spark

# %% [markdown]
# The Latent Dirichlet Allocation is widely used for topic modeling, and is particularly well suited for processing text, since it handles sparse feature vectors very well.  It is described in Wikipedia https://en.wikipedia.org/wiki/Latent_Dirichlet_allocation, and elsewhere.

# %% [markdown]
# ## Library Imports

# %%
import sys.process._
import org.apache.spark.mllib.clustering.{DistributedLDAModel, LDA}
import org.apache.spark.mllib.clustering.LocalLDAModel
import org.apache.spark.rdd.RDD
import org.apache.spark.sql.DataFrame
import org.apache.spark.mllib.linalg.{Vector, Vectors}
import scala.collection.mutable
import scala.io.Source

# %% [markdown]
# - here are some os commands that are used to import data

# %%
"ls -lrth LDAModels"!
# Out:
# total 8.0K
# drwxr-xr-x 2 root root 4.0K Nov 14 21:36 trainedModel-1-vocab
# drwxr-xr-x 4 root root 4.0K Nov 14 21:38 trainedModel-1
# warning: there was one feature warning; re-run with -feature for details
# 0

# %% [markdown]
# ## Visualize with Brunel
#
# In order to use Brunel, it must be downloaded from the website. This is possible by using the "%AddJar" function as follows:

# %%
# %AddJar -magic https://brunelvis.org/jar/spark-kernel-brunel-all-2.5.jar -f
# Out:
# Starting download from https://brunelvis.org/jar/spark-kernel-brunel-all-2.5.jar
# Finished download of spark-kernel-brunel-all-2.5.jar

# %% [markdown]
# ## Display Known Categories

# %% [markdown]
# - the newsgroup dataset is organized into topics directories.  There are 20 directories, each with 1000 news items.

# %%
val categories = ("ls 20_newsgroups"!!).split("\n")
categories.foreach(println)
# Out:
# alt.atheism
# comp.graphics
# comp.os.ms-windows.misc
# comp.sys.ibm.pc.hardware
# comp.sys.mac.hardware
# comp.windows.x
# misc.forsale
# rec.autos
# rec.motorcycles
# rec.sport.baseball
# rec.sport.hockey
# sci.crypt
# sci.electronics
# sci.med
# sci.space
# soc.religion.christian
# talk.politics.guns
# talk.politics.mideast
# talk.politics.misc
# talk.religion.misc
# categories = Array(alt.atheism, comp.graphics, comp.os.ms-windows.misc, comp.sys.ibm.pc.hardware, comp.sys.mac.hardware, comp.windows.x, misc.forsale, rec.autos, rec.motorcycles, rec.sport.baseball, rec.sport.hockey, sci.crypt, sci.electronics, sci.med, sci.space, soc.religion.christian, talk.politics.guns, talk.politics.mideast, talk.politics.misc, talk.religion.misc)
# warning: there was one feature warning; re-run with -feature for details
# [alt.atheism, comp.graphics, comp.os.ms-windows.misc, comp.sys.ibm.pc.hardware, comp.sys.mac.hardware, comp.windows.x, misc.forsale, rec.autos, rec.motorcycles, rec.sport.baseball, rec.sport.hockey, sci.crypt, sci.electronics, sci.med, sci.space, soc.religion.christian, talk.politics.guns, talk.politics.mideast, talk.politics.misc, talk.religion.misc]

# %% [markdown]
# # Load Data

# %% [markdown]
# - We use a pre-calculated LDA model as computed in (TODO: Add a notebook for calculating model?)
# - The model follows the standard Spark ldaModel format
#     - the vocabulary is a special format, and is loaded for display purposes

# %%
//val filename = "LDAModel/f-1.0-sd-0-nTpc-10-nIts-100-81eada91"
val filename = "LDAModels/trainedModel-1"

val filenameVocab = filename + "-vocab"

val ldaModelLoaded = DistributedLDAModel.load(sc,filename)

 
val vocabLoaded: Map[String, Int] = sc.textFile(filename + "-vocab").
                 map(x=>x.split(",")).map(x=>(x(0).slice(1,x(0).size),
                 x(1).slice(0,x(1).size-1).toInt)).collect.toMap

val vocabArrayLoaded: Map[Int, String] = vocabLoaded.map(x => x._2 -> x._1)
# Out:
# filename = LDAModels/trainedModel-1
# filenameVocab = LDAModels/trainedModel-1-vocab
# ldaModelLoaded = org.apache.spark.mllib.clustering.DistributedLDAModel@4330c304
# vocabLoaded = Map(incident -> 1589, serious -> 400, mario -> 2361, inflammatory -> 5664, boggs -> 1182, embedded -> 3245, speaker -> 2586, orioles -> 5010, terrible -> 6458, lion -> 4706, rate -> 2394, inevitable -> 5623, metabolism -> 1216, lights -> 5734, submitted -> 5065, snow -> 1641, purchasing -> 3174, ecac -> 2349, michael -> 577, stacked -> 4879, looks -> 342, shap -> 3754, postal -> 2768, california -> 1468, mammography -> 1457, anticancer -> 2404, illustrator -> 1773, basenotes -> 4496, accident -> 1616, glean -> 5992, muscles ->...
# Map(incident -> 1589, serious -> 400, mario -> 2361, inflammatory -> 5664, boggs -> 1182, embedded -> 3245, speaker -> 2586, orioles -> 5010, terrible -> 6458, lion -> 4706, rate -> 2394, inevitable -> 5623, metabolism -> 1216, lights -> 5734, submitted -> 5065, snow -> 1641, purchasing -> 3174, ecac -> 2349, michael -> 577, stacked -> 4879, looks -> 342, shap -> 3754, postal -> 2768, california -> 1468, mammography -> 1457, anticancer -> 2404, illustrator -> 1773, basenotes -> 4496, accident -> 1616, glean -> 5992, muscles -> 3791, beneath -> 5591, physically -> 3293, conversations -> 923, conceivably -> 1685, scenario -> 1185, countering -> 4174, ideas -> 949, static -> 3305, footnotes -> 5118, unity -> 5987, rainy -> 5822, newark -> 3813, particularly -> 764, used -> 41, dictatorship -> 3531, conceptual -> 3618, simon -> 3980, minority -> 2551, bikes -> 1165, averages -> 3773, allowed -> 2407, automatic -> 2975, reference -> 5882, widely -> 1435, immoblisers -> 3847, aerobic -> 5368, rethinking -> 6371, secretary -> 2380, checklist -> 4338, conversion -> 1508, invade -> 5196, aliases -> 4102, altitude -> 1086, relativism -> 1483, opinions -> 680, significantly -> 601, beautiful -> 5168, demolish -> 5321, peterborough -> 3201, providing -> 740, pharmacopeial -> 2429, sunday -> 2124, sooooooo -> 3085, writing -> 2051, believing -> 1001, funny -> 1382, blights -> 5799, birthday -> 5103, devastating -> 3147, kotb -> 3856, fordham -> 5729, accpeting -> 4467, explore -> 5207, accommodate -> 2664, printer -> 4489, killed -> 1288, cord -> 4232, thet -> 5068, cells -> 1825, walker -> 3835, lists -> 1635, down -> 110, serial -> 856, slightest -> 2553, elements -> 2467, submarines -> 5779, wash -> 2755, reconstructed -> 6108, interpretations -> 6465, side -> 547, likelihood -> 4625, respects -> 5488, regarding -> 676, conventional -> 3604, cyclelok -> 2347, sensitivity -> 6373, wise -> 1904, dangerous -> 761, racist -> 1574, regarded -> 3134, succeed -> 4395, underway -> 5701, execution -> 3831, niether -> 6054, wanting -> 3076, keith -> 1681, entirely -> 1504, homes -> 2206, mission -> 2154, routine -> 1476, sentient -> 2041, flex -> 1808, bruins -> 1273, kills -> 6459, brad -> 6443, inher -> 3951, measure -> 888, health -> 166, pulling -> 2524, panel -> 1979, gordon -> 2479, stating -> 2274, quality -> 1028, canonically -> 5203, economy -> 1557, futile -> 4804, rolling -> 6163, standings -> 5190, alternatives -> 901, sedan -> 5771, precluded -> 3379, hatching -> 3172, messages -> 384, regardless -> 2011, application -> 767, hypocrisy -> 2422, please -> 107, metallic -> 6451, copyright -> 5413, interesting -> 730, apocalyptic -> 4977, constant -> 3185, trouble -> 811, penn -> 1861, clutch -> 2728, desktop -> 912, supercede -> 4547, compeling -> 3035, licenses -> 3804, cheney -> 2241, screaming -> 5045, lookup -> 3102, emulate -> 2741, seeking -> 1947, secret -> 861, finger -> 1834, read -> 130, capabilities -> 1470, number -> 85, mass -> 618, able -> 139, mithras -> 2186, participant -> 6056, papers -> 1249, flicked -> 3471, catholicism -> 3881, behind -> 274, clemens -> 2731, ineffect -> 4480, failure -> 4283, wiretap -> 951, ways -> 773, rounding -> 1889, format -> 5607, grounds -> 2300, blanked -> 5620, mother -> 999, continuous -> 1788, simulate -> 4461, chief -> 2690, organization -> 1029, despite -> 1890, drive -> 185, winning -> 1088, antonio -> 3242, permanently -> 5760, database -> 969, filip -> 3381, njihk -> 3753, moral -> 971, bangles -> 3815, observatory -> 3199, recipes -> 1846, fullfill -> 3511, stock -> 2392, acclimate -> 5654, bullhorn -> 4337, monitored -> 6195, weaver -> 3897, jartsu -> 2890, introducing -> 4737, enhancing -> 6134, duration -> 3567, resending -> 6173, replica -> 2018, biopsy -> 2146, socialist -> 5703, narrative -> 4408, intelligent -> 2999, depended -> 4903, elliptic -> 3692, refuses -> 5520, massacres -> 3588, toro -> 3372, adminstrators -> 1686, baking -> 3151, program -> 252, organized -> 6050, ...

# %% [markdown]
# ## Displaying Topics and top 75 words for each topic

# %% [markdown]
# The model generated here uses only 10 topics, which is not enough for the 20 directories, but more than the 7 topics associated with these directories (sci, comp, etc.).  We expect an imperfect characterization, but some topics appear to be sensible.  Again, we confirm that our dataset is the same one generated by spotchecking that topic 0 has "anonymous" at the top of the list with a score of 0.0126

# %%
var idx = 0
val topicIndices = ldaModelLoaded.describeTopics(maxTermsPerTopic = 75)
topicIndices.foreach { case (terms, termWeights) =>
  println("TOPIC:" + idx)
  terms.zip(termWeights).foreach { case (term, weight) =>
    println(s"${vocabArrayLoaded(term.toInt)}\t$weight")
  }
    idx += 1
  println()
}
# Out:
# TOPIC:0
# anonymous	0.012643275631369468
# internet	0.01199892653846487
# system	0.011489389159339945
# email	0.010461753442982532
# information	0.010033859874241645
# many	0.009046697848641316
# most	0.008985058416534403
# these	0.008776317737127445
# privacy	0.00870315316139373
# mail	0.008168184471456088
# address	0.007318294146922494
# anonymity	0.006893699748457801
# their	0.006457573336484874
# access	0.005735232098296366
# usenet	0.0056810127282647055
# computer	0.0054274783521739735
# sites	0.005346644944619072
# network	0.005201538796310405
# user	0.004953510922416698
# message	0.004673200538625899
# files	0.004580725684189369
# associated	0.0045489408314838406
# identity	0.0044313548110878585
# where	0.004270628694089294
# currently	0.004267651379416461
# over	0.004165226488264872
# find	0.0041167933944265675
# rights	0.004083307820384657
# file	0.0040832693812494865
# been	0.0040562934952105565
# users	0.004045788261142567
# server	0.003992542724717023
# generally	0.0038020822540080707
# posting	0.003798796389884891
# local	0.003773751055946153
# even	0.0037573618620105943
# make	0.0037289729101210862
# only	0.0036960669789951788
# government	0.0036344423285177914
# account	0.003578804482137406
# others	0.0035467992079616707
# such	0.0034308515403937596
# completely	0.003321974354447616
# administrators	0.0032001833306898363
# identification	0.0032001833306898363
# also	0.0031653029089042098
# security	0.003131931110872147
# machine	0.0031144293971630964
# data	0.0030928056209617964
# because	0.0030675159792888412
# unix	0.002962967210403152
# addresses	0.0029561892262632418
# does	0.0027958006017153284
# future	0.002775189545035099
# software	0.0027269626561615278
# traffic	0.0027077152056260486
# could	0.0026478551396564055
# multiple	0.002596630173681546
# services	0.002564817608123813
# based	0.0025513619882595296
# very	0.0025399194105392045
# used	0.0025234547931533183
# given	0.002421777109212595
# directory	0.002400506423039005
# certain	0.0023461015181487585
# uses	0.0023324326162761817
# mailing	0.0023148936946682554
# still	0.0022471633636785573
# windows	0.0022271449678313484
# protocols	0.0022152476115405244
# basic	0.0021954829870994425
# without	0.0021947167951430696
# means	0.002174436936710863
# should	0.002109976708581475
# networks	0.0020984608129160686
#
# TOPIC:1
# encryption	0.01481548780905835
# government	0.013693226139575654
# same	0.00917146448637624
# need	0.008240628107969715
# technology	0.008139930495373543
# their	0.007183173290601083
# something	0.006766296090831116
# chip	0.006469680915325586
# been	0.006171461594235087
# these	0.0059045164375036395
# access	0.005847120158064098
# happy	0.005603076222664396
# available	0.00548497221412721
# protect	0.005388515874076705
# agencies	0.005319075322988041
# private	0.005282906304730342
# using	0.005249530819761519
# while	0.005163165996759463
# privacy	0.004939044205308935
# keys	0.004885169951054146
# enforcement	0.004843213697876329
# data	0.004711345888801263
# security	0.004526942833665887
# escrow	0.004307431484733102
# only	0.004260597800971894
# good	0.004231513645448798
# trust	0.0042300672734331
# used	0.004193811945770456
# years	0.004172900885045008
# algorithm	0.0040460756830254276
# like	0.004019280159989209
# crypto	0.004012003716182171
# department	0.003986195578576636
# also	0.0038950027056245443
# university	0.00387772843506903
# such	0.0038423456932368473
# system	0.0038223748388668145
# president	0.003766722246642925
# computer	0.0037300403920958636
# shape	0.0036874134538965107
# secure	0.0036869235041141154
# even	0.0036848084060854026
# devices	0.0036075209708874988
# public	0.0036022686470649538
# problem	0.003507914457784561
# clipper	0.003480578218410309
# program	0.003468772005425765
# than	0.0034577344301703707
# national	0.0034332221922516045
# networks	0.0034031725646359264
# because	0.003384812160669317
# analysis	0.0033688168833090927
# administration	0.003364296876720641
# were	0.003318460862452665
# those	0.003263935155515638
# virus	0.0032102877405951608
# most	0.0030800368851456946
# companies	0.0030787728749044493
# both	0.0029921598620073434
# release	0.002983325725514063
# phone	0.002904906055515879
# piece	0.002866279221574554
# does	0.002847779391408646
# industry	0.0027867860338209325
# ensure	0.0027706717846006147
# telephone	0.0027666088033137144
# neural	0.0027591928042137266
# hamburg	0.0027336124480915047
# communications	0.002732267746144238
# each	0.0026635548796541883
# policy	0.0026151792710929775
# review	0.00259593285943427
# device	0.002505942069077133
# give	0.0024910936141342255
# legal	0.00248167714379094
#
# TOPIC:2
# university	0.01747426002699005
# first	0.01564696336227368
# series	0.013344088641055397
# please	0.010765995623060383
# thanks	0.010222466073077538
# toronto	0.009595869105575349
# anyone	0.008051897045693554
# leads	0.006728893205584262
# john	0.006421315501827411
# games	0.006075526845872115
# world	0.005555934201031929
# shots	0.00551299180054744
# game	0.005271125864908158
# software	0.005210020469986399
# second	0.0051227419492127476
# looking	0.004741343541060086
# third	0.004266983106075402
# over	0.004261906942452582
# very	0.00426078861584661
# year	0.004258044265131239
# fans	0.004055901959950126
# drivers	0.004023797418035833
# playoff	0.003979883617843636
# scored	0.0039582777726165416
# each	0.003939005309122572
# send	0.0039191886985088615
# caps	0.003917802206524398
# still	0.003906708684836568
# louis	0.003888392894410231
# division	0.003877738696263127
# made	0.0038492309142511213
# cards	0.0036676859186363614
# chicago	0.003627242605900934
# mark	0.0034764793063549594
# post	0.0034594819203818262
# baseball	0.00333042157870435
# give	0.003287289926535095
# tickets	0.0032435213575135635
# stanley	0.003229543869503341
# asking	0.0031872168457242156
# april	0.0031852194838270036
# thank	0.0031433679193327486
# sale	0.003084294677662611
# history	0.002944329964770533
# washington	0.002867371564162758
# before	0.0027073826226979335
# except	0.0026724400594896197
# selanne	0.002662373096320671
# winnipeg	0.002662373096320671
# vancouver	0.002662373096320671
# detroit	0.002662373096320671
# thought	0.002635139087821602
# played	0.002623383575457322
# defeated	0.002618780013252517
# bruins	0.0025880193011386917
# kevin	0.0025818846890885597
# miami	0.0025813261096414974
# baltimore	0.002566519314307648
# pittsburgh	0.0025421802371365346
# company	0.002507548738082424
# called	0.0024567616062952744
# watching	0.002316476661630792
# mailing	0.0022630291696461814
# west	0.0022484934213184717
# list	0.002244594485609893
# round	0.0022247870874727914
# team	0.0022202955917813502
# final	0.0022055132364455425
# lead	0.0021472224947876265
# state	0.0021324157313741916
# doubt	0.002109978906569599
# starting	0.0020820066314624595
# motif	0.0020663151460103718
# couple	0.0020435257940370063
# results	0.0020280150079375657
#
# TOPIC:3
# only	0.009411420577235471
# sense	0.007210635156214296
# does	0.007033954317302951
# chromium	0.006979952220709531
# been	0.006797482567685464
# make	0.00671900971640935
# think	0.006636586734710476
# whether	0.006235547074069614
# should	0.005847690427809187
# well	0.005791411731158775
# video	0.005727147082655768
# good	0.005343674818135231
# bike	0.005154191000259808
# their	0.004994773098460049
# work	0.004552730955378682
# them	0.004530913709126543
# very	0.0044173357761951495
# also	0.004348773333872266
# really	0.004259259513995288
# going	0.004201158841885855
# world	0.004124516965766642
# best	0.004080783686889266
# time	0.004028133725026082
# because	0.003991911887438345
# were	0.0039802051400691036
# evil	0.003979070960441069
# enough	0.003960408636639922
# thing	0.003941481801035652
# those	0.003663817148654925
# weight	0.003589460848287765
# insulin	0.003484858955560142
# muscle	0.003484858955560142
# picolinate	0.003484858955560142
# abus	0.0034742535066413275
# like	0.0034289600897566817
# much	0.0034192928280323016
# saying	0.0033983786568282377
# always	0.0033970971625565637
# never	0.0033776333547391253
# could	0.0033549596150361867
# behind	0.003211698803223023
# believe	0.003194533587660525
# heard	0.0031407749725108004
# blue	0.0031398180406417833
# since	0.0031354648126852465
# sure	0.003110786015053176
# lock	0.0031051391385605027
# said	0.003004724533353237
# most	0.0029897746480565717
# each	0.002983538354210394
# armenians	0.0029809051460347965
# apple	0.0029321917510996944
# stop	0.002899400387415749
# even	0.002877406135249154
# someone	0.00285415080627638
# university	0.0027525260254457466
# last	0.0026806907142588082
# accept	0.0025581576620454616
# being	0.00255381059733316
# increase	0.002545204647177561
# cable	0.002476118521652777
# moral	0.0024676891927125485
# batting	0.0024345909840635858
# measure	0.002432860944741586
# take	0.0024318921595686224
# human	0.002383091733076931
# least	0.0023822524245631378
# important	0.002304328983080431
# locks	0.0022853138717186714
# deal	0.0022292817432669914
# these	0.002167229964659237
# today	0.002158995444563394
# party	0.0021235310335046124
# source	0.0021185149587793516
# made	0.0021089037882005787
#
# TOPIC:4
# windows	0.01657842405176562
# into	0.01362835264945759
# jewish	0.01015527904530455
# after	0.008602098871499021
# using	0.008475168073897537
# drive	0.008344585003645563
# file	0.008208433388043626
# under	0.007833718642413171
# like	0.007321924922685467
# also	0.0072717990137003705
# back	0.00700405930948905
# running	0.0066547097126617005
# join	0.0066467846082723225
# still	0.006522573609917412
# disk	0.0064262130718070794
# time	0.006303352847223693
# here	0.005610241801897752
# change	0.005389217706563436
# think	0.005336168930671571
# claim	0.005021454150181768
# university	0.004946647648746804
# same	0.004750173975543337
# computer	0.004636000905616887
# suppose	0.004439228609400007
# define	0.0044317170682578785
# over	0.004383807263620125
# place	0.004317583429106028
# anyone	0.0042165352610483665
# because	0.004026181915268109
# atheists	0.004020353236643306
# spacecraft	0.003914175318719133
# religious	0.003892319903308746
# scodal	0.003848522953483014
# test	0.0038278023870731573
# those	0.00378915448407683
# state	0.003760364929220043
# years	0.0036811144700697653
# long	0.0036699190898066164
# want	0.003646842990228821
# nation	0.0034311596438503793
# drives	0.0034254133638487467
# since	0.0034206968415331786
# part	0.0033121285022710226
# based	0.003294505492558021
# country	0.003180247407901652
# group	0.003109311812078122
# look	0.0030657852325479146
# than	0.002968530110943559
# family	0.002956136554511995
# david	0.0029455572546939063
# religion	0.002942379867019922
# work	0.002907636853633666
# joined	0.0028972828443308567
# space	0.0028834867441409006
# were	0.0028613996975672966
# research	0.0028239743670067817
# college	0.0028062235626794742
# harddisk	0.002764527775539911
# require	0.0027338748408080303
# believe	0.0027277460391653416
# having	0.0026766271845270547
# mode	0.002635685834475992
# many	0.0026096455305374628
# problem	0.0025587060160662603
# speed	0.0025347934378678696
# word	0.0025009937309050643
# gets	0.0024492766489879083
# wondering	0.0024281039612903156
# need	0.002419129567711896
# real	0.0023981847770229723
# support	0.0023960971256430296
# function	0.0023925968673379192
# where	0.002351253408446471
# units	0.0023353182076868055
# current	0.0023018578938330783
#
# TOPIC:5
# university	0.010467701978271175
# believe	0.009710904971340454
# news	0.009039133762435212
# really	0.0081584830898795
# things	0.007301015791177509
# than	0.007152422137312646
# said	0.0064284145986875495
# someone	0.006297580809873697
# evolution	0.0059402292520382505
# only	0.00582813147166806
# fact	0.00582775357491166
# enough	0.005669513372289536
# think	0.004995611697431488
# read	0.004805390174990622
# evidence	0.004722194271550511
# belief	0.004634106837398263
# make	0.004512305056030809
# even	0.004253835658820602
# perhaps	0.00423358981056179
# radio	0.0042135816904321595
# mean	0.004147271254148472
# every	0.004044984058978793
# those	0.0038373521103410215
# religious	0.0037933411513505723
# theory	0.0037438713999714533
# beliefs	0.0036812665249846012
# press	0.0035572248318190398
# else	0.00350475402705437
# between	0.0034762865615605497
# might	0.0034353173667108646
# also	0.0033552574531741743
# maybe	0.0033345429434129045
# fire	0.0033309384635907898
# then	0.0033264640872788256
# been	0.003317611966948764
# never	0.0032800148989558624
# creation	0.003249793289359336
# cause	0.003159088070438072
# difference	0.0031082175135053757
# illinois	0.003073464353824994
# different	0.003069379116904226
# like	0.0029460762527453227
# them	0.0028900747803706555
# opinions	0.0028540359490622945
# change	0.002816408274442823
# service	0.0028058309413480156
# reported	0.0028044699497185464
# feel	0.002800205231245364
# find	0.002751238819624096
# love	0.0027423342564316874
# world	0.0026841901034129474
# great	0.002642193903249871
# explain	0.0026412729493847696
# light	0.0026228900694397943
# kind	0.002561562494224994
# could	0.002516585239458934
# sense	0.0024952862163511555
# dark	0.002474484282074642
# start	0.002470386486694099
# religion	0.0024292201171011063
# wants	0.002389158446201289
# provide	0.0022717620640987993
# david	0.0022368919519904855
# agnostic	0.0022291679268804554
# north	0.002172639998588009
# space	0.0021351557346898356
# four	0.0021153482040003812
# miles	0.0020631391827359877
# trying	0.002048688636465093
# experience	0.002019528668178482
# course	0.001985308464315217
# blue	0.0019785872497747703
# quote	0.0019698136027478563
# based	0.0019678505296598374
# deleted	0.0019592281286192506
#
# TOPIC:6
# know	0.013018871914448116
# their	0.007967604967411852
# last	0.007463893438451421
# them	0.006969054095081095
# police	0.006899629938354797
# should	0.006624049878912861
# could	0.0066002450479568636
# only	0.00597558918578598
# through	0.005842616891946801
# like	0.005762451813776054
# palestinian	0.005747628426363572
# even	0.00572486933780479
# over	0.005358404460104384
# never	0.004978620116823782
# because	0.004957355013917386
# problem	0.00464208045793398
# come	0.004553859826707495
# were	0.004518375078028546
# still	0.004317420868676282
# back	0.004153037486619452
# force	0.004133059702415278
# cubs	0.004096004985416593
# local	0.003939796586526259
# also	0.0039287025124299674
# good	0.003841974882574129
# down	0.003806961321903387
# insurance	0.003793746112195685
# getting	0.003782101812226447
# been	0.0036774285310198925
# give	0.003626463708032446
# card	0.0035804911668549763
# year	0.0035741395405660312
# right	0.003511957769709263
# always	0.0034588445876479277
# cult	0.0034562901076268344
# yankee	0.0034537133598728912
# wade	0.0034356412214284872
# lciii	0.0034128433357041212
# than	0.003308191882238573
# before	0.0030940085159869304
# george	0.0030885877666585043
# live	0.0030720303617230594
# yanks	0.003018186176068137
# wonder	0.003002037495811986
# asante	0.0029774860699067636
# ethernet	0.0029774860699067636
# fans	0.002861423312203223
# each	0.0028354277375380083
# long	0.0026342413089173035
# really	0.00257692040658728
# then	0.0025729296815330165
# israeli	0.002568352932405324
# keyboard	0.002550897787721052
# members	0.0024857627555943916
# make	0.0024782940589807706
# many	0.002473218937489176
# everyone	0.002470769313964417
# time	0.0024579081586523655
# going	0.002444447463981227
# team	0.0024398788142874495
# worked	0.0024307745905895804
# little	0.0024051684728970905
# another	0.0023945318031130002
# stuff	0.0022801036848304765
# sure	0.002261084905102919
# supposed	0.002242101375210329
# nothing	0.0022407496677854743
# told	0.002240273430026759
# players	0.002225966235003425
# around	0.0021607936760629372
# palestinians	0.0021587682666290506
# gotten	0.002135089362284351
# kratz	0.002131845267566529
# start	0.0021231408556401025
# state	0.0021005459884366694
#
# TOPIC:7
# does	0.01085397954073694
# because	0.008002311445339248
# much	0.0076185779675855035
# being	0.006605090252859039
# cipher	0.005851704795223865
# like	0.005849397392869853
# could	0.0055843477813147845
# were	0.0055539784224081495
# question	0.005473001523322474
# very	0.005449452064391308
# make	0.005405625925205412
# probably	0.005012088615567677
# power	0.004994482111361154
# good	0.0049476602405568474
# between	0.004883864527402594
# problem	0.004775588229267334
# money	0.004754203406679468
# want	0.0047223710711638694
# cellular	0.004675432739209709
# life	0.004396148787871462
# need	0.004360988839626503
# criminals	0.004241462220315811
# person	0.0041776382826414415
# without	0.004170665760531206
# these	0.003855944282753539
# able	0.0037969160236599794
# kill	0.003751006981896168
# human	0.003748398285512015
# willing	0.0037418025766412736
# steal	0.0037177898022981454
# drugs	0.003560882731463065
# high	0.0034852717061478835
# legal	0.0034667792352081122
# sure	0.0034265947873292424
# making	0.003420058156423049
# into	0.0034054323074373225
# clipper	0.0034020621610859262
# then	0.0033782378338527803
# systems	0.0033557127138222845
# think	0.0033081162337046644
# seen	0.0032947997304534466
# doing	0.0032729500594841075
# anybody	0.0032485028987162805
# southern	0.003247470958404258
# should	0.003234641687529119
# might	0.0032207257690468434
# friend	0.003192132809610661
# stolen	0.003184370297486155
# communications	0.0031654717326508376
# never	0.003132769305874082
# quite	0.0031150113536501933
# selling	0.003064611347861876
# means	0.003064310010443901
# going	0.0030211930855562445
# world	0.0029995573184523525
# down	0.0029596624169523768
# know	0.0029595419759482432
# zoology	0.0029321903318413156
# since	0.002886759821624167
# city	0.0028428526125253394
# only	0.002776493946123483
# pressure	0.002755627458495839
# tell	0.0027407214065576857
# oxygen	0.0026462311035534316
# even	0.0026243625729735196
# islam	0.0026093218421097742
# devices	0.002607783021638426
# serial	0.0025789384116928554
# elves	0.0025282132298576968
# temperature	0.0025170170119928215
# issue	0.002516869858027521
# given	0.002498396439222572
# freedom	0.0024601012466177056
# harm	0.002451824603350893
# higher	0.002428467298118758
#
# TOPIC:8
# cancer	0.01897281987282188
# information	0.013770086135244096
# breast	0.012777682925598157
# aids	0.011803170454192553
# medical	0.010943792173616879
# booklet	0.010310677149541769
# were	0.010039856800945171
# patients	0.00905845122689094
# april	0.008722410722470668
# number	0.00860008062724315
# should	0.00793079889259155
# health	0.007297481795999656
# patient	0.007176823652996131
# research	0.00702205048758898
# volume	0.00655680125830849
# page	0.006520984156841903
# newsletter	0.0061565926787585925
# hicnet	0.0057733673412697
# their	0.005738578705051698
# national	0.005285586946763767
# drug	0.00522105954919019
# during	0.00510734301633273
# early	0.004868797862503514
# describes	0.004834465705893565
# said	0.004544564350053883
# questions	0.0044024116924745674
# available	0.004396604590646084
# provides	0.004166760556243297
# transmission	0.004135252566207765
# researchers	0.0041234388728786766
# infected	0.0041234388728786766
# drugs	0.003959747666077258
# women	0.0038916129968428153
# education	0.0038751862977558756
# includes	0.0037514172781416763
# companies	0.0037288222846392207
# clinical	0.0037109573008703217
# surgeon	0.0037109573008703217
# used	0.003584795863490059
# most	0.0034627758467772555
# treatment	0.0034404535872638972
# been	0.0033706946137330956
# infection	0.0032984761084632365
# following	0.003294909775322199
# total	0.003268538382706401
# detection	0.0031820317160605443
# guide	0.0031273895431320436
# only	0.0031243344557023
# importance	0.003038072168108018
# child	0.0030302187487899882
# types	0.0029926567432249215
# pamphlet	0.0029744027237831165
# common	0.002972708276027513
# disease	0.002902334475682625
# invasive	0.0028859954561169738
# brochure	0.0028859954561169738
# discusses	0.0028859954561169738
# states	0.002861747847352133
# answers	0.002802135298035161
# both	0.0027661570809171363
# explains	0.002712721498960203
# different	0.002688442876014
# immune	0.002679078785532946
# often	0.0026548056646034097
# case	0.0025954102849490113
# risk	0.002582121773638062
# each	0.0025272480326167164
# found	0.002511689030537362
# concerns	0.002501141505419522
# them	0.002489695684241762
# procedures	0.002479650182762532
# sheets	0.002473515609558867
# addresses	0.0024699995131494774
# american	0.002465878550643491
# than	0.002464084743974269
#
# TOPIC:9
# know	0.013962095548991943
# like	0.012698021708549896
# than	0.011995530578465653
# then	0.008462203661729228
# were	0.008185100922784658
# better	0.007992764395090033
# want	0.006927354305077678
# right	0.006339900843329179
# science	0.005886846679513384
# these	0.005627734828564949
# into	0.005589767544463768
# been	0.0055156161717575085
# many	0.0052958325752800505
# should	0.005030133016182306
# must	0.004944435386313594
# engine	0.004825132601921394
# says	0.004718770042409544
# good	0.004452158908143149
# part	0.004398339596789552
# seems	0.004125086171274554
# think	0.004084432470970334
# most	0.004034064217021951
# movie	0.0038484942594909396
# after	0.0038196726814589605
# once	0.0035826121104269954
# something	0.0034326103407008803
# because	0.003341614561024224
# does	0.0031614219621072972
# very	0.0031201338393694834
# james	0.0030811749545112677
# anything	0.00307870062874407
# take	0.003039867098135666
# color	0.0029443636322168923
# since	0.002883138111277666
# able	0.002860652233720948
# different	0.002820581342528041
# whole	0.0028182354374335357
# church	0.002811341500724958
# christian	0.002800031827554073
# same	0.0027761447016901447
# anyone	0.0027671992002842013
# them	0.0027586370827573105
# sounds	0.002747888305444781
# help	0.0027369022953699514
# could	0.002729253418983698
# jesus	0.0026631243274963584
# real	0.002658383337142649
# book	0.002621088752585224
# great	0.002609870854755423
# already	0.0026076142609919887
# shown	0.002576468084208852
# drawing	0.0025760997881228934
# mentioned	0.002571609813952075
# compromise	0.0025462677478937487
# dave	0.0025356697925542717
# those	0.002534348741429736
# nothing	0.002521460571859881
# least	0.0024842682482825638
# believe	0.002435993202176831
# later	0.0024203844433827444
# oilers	0.0024094308316120043
# pocklington	0.0024094308316120043
# quicktime	0.002389834885615463
# question	0.0023529350320039715
# before	0.002332027362975994
# possible	0.0023133558813076393
# wrong	0.0022831923055528307
# values	0.0022710001619628737
# next	0.002254979115265942
# mind	0.002250465830552087
# made	0.0022418288515890145
# logic	0.0021910613982268476
# original	0.0021797181555406903
# make	0.002171998657341693
# time	0.002165409777035911
# idx = 10
# topicIndices = Array((Array(25, 29, 14, 33, 7, 17, 11, 8, 31, 47, 71, 87, 0, 42, 111, 36, 120, 101, 115, 147, 117, 142, 172, 53, 151, 28, 64, 154, 59, 6, 159, 199, 219, 171, 73, 16, 18, 5, 27, 238, 114, 67, 190, 287, 276, 15, 106, 270, 74, 12, 255, 167, 13, 211, 156, 364, 19, 191, 304, 98, 24, 41, 108, 325, 186, 284, 294, 32, 39, 496, 351, 105, 160, 10, 216),Array(0.012643275631369468, 0.01199892653846487, 0.011489389159339945, 0.010461753442982532, 0.010033859874241645, 0.009046697848641316, 0.008985058416534403, 0.008776317737127445, 0.00870315316139373, 0.008168184471456088, 0.007318294146922494, 0.006893699748457801, 0.006457573336484874, 0.005735232098296366, 0.0056810127282647055, 0.0054274783521739735, 0.005346644944619072, 0.0052...
# [([I@63f73ddb,[D@6c250628), ([I@488fb47b,[D@4d2f741e), ([I@64d9784f,[D@f8ba291), ([I@3a12e377,[D@cabffaf), ([I@231ff575,[D@71d244ad), ([I@5cf618bb,[D@f73c20d), ([I@531b3acb,[D@300feb29), ([I@5cd00e53,[D@4da2cc6e), ([I@47e56a73,[D@87c8705), ([I@5402b2cf,[D@f98d59d)]

# %% [markdown]
# # Using Brunel to Visualize each Topic

# %% [markdown]
# Rather than sort through a large list of topics, we select a topic here and use Brunel to generate a word cloud.  This may sometimes be easier, but it is also useful to have the full list as given above.  Here, we visualize topic 6, which appears to have many words associated with what we might expect to be sci.electronics, as well as other sci.xxx topics.
# There are other ways to confirm that this is a good topic assignment, but we are demonstrating how an early effort at characterizing the corpus topics might be carried out.

# %%
val topicToVisualize =  0
val topicDF = sc.parallelize(topicIndices(topicToVisualize)._1.map(x=>vocabArrayLoaded(x)).zip(topicIndices(topicToVisualize)._2)).toDF("word", "weight")
# Out:
# topicToVisualize = 0
# topicDF = [word: string, weight: double]
# [word: string, weight: double]

# %%
# %%brunel data('topicDF') cloud x(word) color(word) size(weight) label(word)
# Out:
#                 'brunel' : 'https://brunelvis.org/js...
#          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/brunel.2.5.css" charset="utf-8">
#          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/sumoselect.css" charset="utf-8">
#          <style>  </style>
#          <div id="controlsId945ccf07-630a-4b36-a8b6-a697f59215dc" class="brunel"/>
# <svg id="visidabb723cc-29b6-4e00-990f-2af14b870f9e" width="500" height="400"></svg>
#
# <script>
# require.config({
#             waitSeconds: 60,
#             paths: {
#                 'd3': '//cdnjs.cloudflare.com/ajax/libs/d3/4.2.1/d3.min',
#                 'topojson' : '//cdnjs.cloudflare.com/ajax/libs/topojson/1.6.20/topojson.min',
#                 'brunel' : 'https://brunelvis.org/js/brunel.2.5.min',
#                 'brunelControls' : 'https://brunelvis.org/js/brunel.controls.2.5.min'
#             },
#
#             shim: {
#                'brunel' : {
#                     exports: 'BrunelD3',
#                     deps: ['d3', 'topojson'],
#                     init: function() {
#                        return {
#                          BrunelD3 : BrunelD3,
#                          BrunelData : BrunelData
#                       }
#                     }
#                 },
#                'brunelControls' : {
#                     exports: 'BrunelEventHandlers',
#                     init: function() {
#                        return {
#                          BrunelEventHandlers: BrunelEventHandlers,
#                          BrunelJQueryControlFactory: BrunelJQueryControlFactory
#                       }
#                     }
#                 }
#
#             }
#
#         });
#
#         require(["d3"], function(d3) {
#         require(["brunel", "brunelControls"], function(brunel, brunelControls) {
#
#             function  BrunelVis(visId) {
#   "use strict";                                                                       // strict mode
#   var datasets = [],                                      // array of datasets for the original data
#       pre = function(d, i) { return d },                         // default pre-process does nothing
#       post = function(d, i) { return d },                       // default post-process does nothing
#       transitionTime = 200,                                        // transition time for animations
#       charts = [],                                                       // the charts in the system
#       vis = d3.select('#' + visId).attr('class', 'brunel');                     // the SVG container
#
#   BrunelD3.addDefinitions(vis);                                   // ensure standard symbols present
#
#   // Define chart #1 in the visualization //////////////////////////////////////////////////////////
#
#   charts[0] = function(parentNode, filterRows) {
#     var geom = BrunelD3.geometry(parentNode || vis.node(), 0, 0, 1, 1, 0, 0, 0, 138),
#       elements = [];                                              // array of elements in this chart
#
#     // Define groups for the chart parts ///////////////////////////////////////////////////////////
#
#     var chart =  vis.append('g').attr('class', 'chart1')
#       .attr('transform','translate(' + geom.chart_left + ',' + geom.chart_top + ')');
#     var overlay = chart.append('g').attr('class', 'element').attr('class', 'overlay');
#     var zoom = d3.zoom().scaleExtent([1/3,3]);
#     var zoomNode = overlay.append('rect').attr('class', 'overlay')
#       .attr('x', geom.inner_left).attr('y', geom.inner_top)
#       .attr('width', geom.inner_rawWidth).attr('height', geom.inner_rawHeight)
#       .style('cursor', 'default')
#       .node();
#     zoomNode.__zoom = d3.zoomIdentity;
#     chart.append('rect').attr('class', 'background').attr('width', geom.chart_right-geom.chart_left).attr('height', geom.chart_bottom-geom.chart_top);
#     var interior = chart.append('g').attr('class', 'interior zoomNone')
#       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')')
#       .attr('clip-path', 'url(#clip_visidabb723cc-29b6-4e00-990f-2af14b870f9e_chart1_inner)');
#     interior.append('rect').attr('class', 'inner').attr('width', geom.inner_width).attr('height', geom.inner_height);
#     var gridGroup = interior.append('g').attr('class', 'grid');
#     var legends = chart.append('g').attr('class', 'legend')
#       .attr('transform','translate(' + (geom.chart_right-geom.chart_left - 3) + ',' + 0 + ')');
#     vis.select('defs').append('clipPath').attr('id', 'clip_visidabb723cc-29b6-4e00-990f-2af14b870f9e_chart1_inner').append('rect')
#       .attr('x', 0).attr('y', 0)
#       .attr('width', geom.inner_rawWidth+1).attr('height', geom.inner_rawHeight+1);
#     var scale_x = d3.scaleLinear(), scale_y = d3.scaleLinear();
#     var base_scales = [scale_x, scale_y];                           // untransformed original scales
#     zoom.on('zoom', function(t, time) {
#         t = t || d3.event.transform;
#         zoomNode.__zoom = t;
#         interior.attr('class', 'interior ' + BrunelD3.zoomLabel(t.k));;
#         interior.attr('transform', d3.zoomTransform(zoomNode));
#     });
#
#     // Define element #1 ///////////////////////////////////////////////////////////////////////////
#
#     elements[0] = function() {
#       var original, processed,                           // data sets passed in and then transformed
#         element, data,                                 // brunel element information and brunel data
#         selection, merged;                                      // d3 selection and merged selection
#       var elementGroup = interior.append('g').attr('class', 'element1')
#         .attr('transform','translate(' + geom.inner_width/2 + ',' + geom.inner_height/2 + ')'),
#         main = elementGroup.append('g').attr('class', 'main'),
#         labels = BrunelD3.undoTransform(elementGroup.append('g').attr('class', 'labels').attr('aria-hidden', 'true'), elementGroup);
#
#       function makeData() {
#         original = datasets[0];
#         if (filterRows) original = original.retainRows(filterRows);
#         processed = pre(original, 0);
#         processed = post(processed, 0);
#         var f0 = processed.field('word'),
#           f1 = processed.field('weight'),
#           f2 = processed.field('#row'),
#           f3 = processed.field('#selection');
#         var keyFunc = function(d) { return f0.value(d) };
#         data = {
#           word:         function(d) { return f0.value(d.row) },
#           weight:       function(d) { return f1.value(d.row) },
#           $row:         function(d) { return f2.value(d.row) },
#           $selection:   function(d) { return f3.value(d.row) },
#           word_f:       function(d) { return f0.valueFormatted(d.row) },
#           weight_f:     function(d) { return f1.valueFormatted(d.row) },
#           $row_f:       function(d) { return f2.valueFormatted(d.row) },
#           $selection_f: function(d) { return f3.valueFormatted(d.row) },
#           _split:       function(d) { return f0.value(d.row)+ '|' + f1.value(d.row) },
#           _key:         keyFunc,
#           _rows:        BrunelD3.makeRowsWithKeys(keyFunc, processed.rowCount())
#         };
#       }
#       // Aesthetic Functions
#       var scale_color = d3.scaleOrdinal()
#         .domain(['access', 'account', 'address', 'addresses', 'administrators', 'also', 'anonymity', 'anonymous', 'associated', 'based', 'basic', 'because', 'been', 'certain', 'completely', 'computer', 'could', 'currently', 'data', 'directory', 'does', 'email', 'even', 'file', 'files', 'find', 'future', 'generally', 'given', 'government', 'identification', 'identity', 'information', 'internet', 'local', 'machine', 'mail', 'mailing', 'make', 'many', 'means', 'message', 'most', 'multiple', 'network', 'networks', 'only', 'others', 'over', 'posting', 'privacy', 'protocols', 'rights', 'security', 'server', 'services', 'should', 'sites', 'software', 'still', 'such', 'system', 'their', 'these', 'traffic', 'unix', 'used', 'usenet', 'user', 'users', 'uses', 'very', 'where', 'windows', 'without'])
#         .range([ '#00538A', '#C10020', '#F4C800', '#007D34', '#803E75', '#FF6800',
#           '#817066', '#FFB300', '#F6

# %% [markdown]
# These words appear to be related to the manually labeled topic of `sci.crypt`.
#
# It is not unusual to see imperfect clustering.  After all, the categories were assigned by hand, and we are using an algorithm to assign labels.  We see behavior like this in even the simplest K Means model (TODO: Link to KMeans Notebook).
# The great benefit of unsupervised learning is the ability to give structure to vast quantities of data that are otherwise difficult for a human to spot.  Since we view this as an aid to understanding, we don't need to have a perfect correspondence between the annotations and the discovered topics.  Looking at Topic 1, we also see words that seem to be related to the `sci.crypt` topic.

# %%
val topicToVisualize =  1
val topicDF = sc.parallelize(topicIndices(topicToVisualize)._1.map(x=>vocabArrayLoaded(x)).zip(topicIndices(topicToVisualize)._2)).toDF("word", "weight")
# Out:
# topicToVisualize = 1
# topicDF = [word: string, weight: double]
# [word: string, weight: double]

# %%
# %%brunel data('topicDF') cloud x(word) color(word) size(weight) label(word)
# Out:
#                 'brunel' : 'https://brunelvis.org/js...
#          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/brunel.2.5.css" charset="utf-8">
#          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/sumoselect.css" charset="utf-8">
#          <style>  </style>
#          <div id="controlsId8ceeace0-4fa8-4a44-b263-46d6c00c742d" class="brunel"/>
# <svg id="viside951c13b-d989-492c-84ce-d4d7a00e53cf" width="500" height="400"></svg>
#
# <script>
# require.config({
#             waitSeconds: 60,
#             paths: {
#                 'd3': '//cdnjs.cloudflare.com/ajax/libs/d3/4.2.1/d3.min',
#                 'topojson' : '//cdnjs.cloudflare.com/ajax/libs/topojson/1.6.20/topojson.min',
#                 'brunel' : 'https://brunelvis.org/js/brunel.2.5.min',
#                 'brunelControls' : 'https://brunelvis.org/js/brunel.controls.2.5.min'
#             },
#
#             shim: {
#                'brunel' : {
#                     exports: 'BrunelD3',
#                     deps: ['d3', 'topojson'],
#                     init: function() {
#                        return {
#                          BrunelD3 : BrunelD3,
#                          BrunelData : BrunelData
#                       }
#                     }
#                 },
#                'brunelControls' : {
#                     exports: 'BrunelEventHandlers',
#                     init: function() {
#                        return {
#                          BrunelEventHandlers: BrunelEventHandlers,
#                          BrunelJQueryControlFactory: BrunelJQueryControlFactory
#                       }
#                     }
#                 }
#
#             }
#
#         });
#
#         require(["d3"], function(d3) {
#         require(["brunel", "brunelControls"], function(brunel, brunelControls) {
#
#             function  BrunelVis(visId) {
#   "use strict";                                                                       // strict mode
#   var datasets = [],                                      // array of datasets for the original data
#       pre = function(d, i) { return d },                         // default pre-process does nothing
#       post = function(d, i) { return d },                       // default post-process does nothing
#       transitionTime = 200,                                        // transition time for animations
#       charts = [],                                                       // the charts in the system
#       vis = d3.select('#' + visId).attr('class', 'brunel');                     // the SVG container
#
#   BrunelD3.addDefinitions(vis);                                   // ensure standard symbols present
#
#   // Define chart #1 in the visualization //////////////////////////////////////////////////////////
#
#   charts[0] = function(parentNode, filterRows) {
#     var geom = BrunelD3.geometry(parentNode || vis.node(), 0, 0, 1, 1, 0, 0, 0, 138),
#       elements = [];                                              // array of elements in this chart
#
#     // Define groups for the chart parts ///////////////////////////////////////////////////////////
#
#     var chart =  vis.append('g').attr('class', 'chart1')
#       .attr('transform','translate(' + geom.chart_left + ',' + geom.chart_top + ')');
#     var overlay = chart.append('g').attr('class', 'element').attr('class', 'overlay');
#     var zoom = d3.zoom().scaleExtent([1/3,3]);
#     var zoomNode = overlay.append('rect').attr('class', 'overlay')
#       .attr('x', geom.inner_left).attr('y', geom.inner_top)
#       .attr('width', geom.inner_rawWidth).attr('height', geom.inner_rawHeight)
#       .style('cursor', 'default')
#       .node();
#     zoomNode.__zoom = d3.zoomIdentity;
#     chart.append('rect').attr('class', 'background').attr('width', geom.chart_right-geom.chart_left).attr('height', geom.chart_bottom-geom.chart_top);
#     var interior = chart.append('g').attr('class', 'interior zoomNone')
#       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')')
#       .attr('clip-path', 'url(#clip_viside951c13b-d989-492c-84ce-d4d7a00e53cf_chart1_inner)');
#     interior.append('rect').attr('class', 'inner').attr('width', geom.inner_width).attr('height', geom.inner_height);
#     var gridGroup = interior.append('g').attr('class', 'grid');
#     var legends = chart.append('g').attr('class', 'legend')
#       .attr('transform','translate(' + (geom.chart_right-geom.chart_left - 3) + ',' + 0 + ')');
#     vis.select('defs').append('clipPath').attr('id', 'clip_viside951c13b-d989-492c-84ce-d4d7a00e53cf_chart1_inner').append('rect')
#       .attr('x', 0).attr('y', 0)
#       .attr('width', geom.inner_rawWidth+1).attr('height', geom.inner_rawHeight+1);
#     var scale_x = d3.scaleLinear(), scale_y = d3.scaleLinear();
#     var base_scales = [scale_x, scale_y];                           // untransformed original scales
#     zoom.on('zoom', function(t, time) {
#         t = t || d3.event.transform;
#         zoomNode.__zoom = t;
#         interior.attr('class', 'interior ' + BrunelD3.zoomLabel(t.k));;
#         interior.attr('transform', d3.zoomTransform(zoomNode));
#     });
#
#     // Define element #1 ///////////////////////////////////////////////////////////////////////////
#
#     elements[0] = function() {
#       var original, processed,                           // data sets passed in and then transformed
#         element, data,                                 // brunel element information and brunel data
#         selection, merged;                                      // d3 selection and merged selection
#       var elementGroup = interior.append('g').attr('class', 'element1')
#         .attr('transform','translate(' + geom.inner_width/2 + ',' + geom.inner_height/2 + ')'),
#         main = elementGroup.append('g').attr('class', 'main'),
#         labels = BrunelD3.undoTransform(elementGroup.append('g').attr('class', 'labels').attr('aria-hidden', 'true'), elementGroup);
#
#       function makeData() {
#         original = datasets[0];
#         if (filterRows) original = original.retainRows(filterRows);
#         processed = pre(original, 0);
#         processed = post(processed, 0);
#         var f0 = processed.field('word'),
#           f1 = processed.field('weight'),
#           f2 = processed.field('#row'),
#           f3 = processed.field('#selection');
#         var keyFunc = function(d) { return f0.value(d) };
#         data = {
#           word:         function(d) { return f0.value(d.row) },
#           weight:       function(d) { return f1.value(d.row) },
#           $row:         function(d) { return f2.value(d.row) },
#           $selection:   function(d) { return f3.value(d.row) },
#           word_f:       function(d) { return f0.valueFormatted(d.row) },
#           weight_f:     function(d) { return f1.valueFormatted(d.row) },
#           $row_f:       function(d) { return f2.valueFormatted(d.row) },
#           $selection_f: function(d) { return f3.valueFormatted(d.row) },
#           _split:       function(d) { return f0.value(d.row)+ '|' + f1.value(d.row) },
#           _key:         keyFunc,
#           _rows:        BrunelD3.makeRowsWithKeys(keyFunc, processed.rowCount())
#         };
#       }
#       // Aesthetic Functions
#       var scale_color = d3.scaleOrdinal()
#         .domain(['access', 'administration', 'agencies', 'algorithm', 'also', 'analysis', 'available', 'because', 'been', 'both', 'chip', 'clipper', 'communications', 'companies', 'computer', 'crypto', 'data', 'department', 'device', 'devices', 'does', 'each', 'encryption', 'enforcement', 'ensure', 'escrow', 'even', 'give', 'good', 'government', 'hamburg', 'happy', 'industry', 'keys', 'legal', 'like', 'most', 'national', 'need', 'networks', 'neural', 'only', 'phone', 'piece', 'policy', 'president', 'privacy', 'private', 'problem', 'program', 'protect', 'public', 'release', 'review', 'same', 'secure', 'security', 'shape', 'something', 'such', 'system', 'technology', 'telephone', 'than', 'their', 'these', 'those', 'trust', 'university', 'used', 'using', 'virus', 'were', 'while', 'years'])
#         .range([ '#00538A', '#C10020', '#F4C800', '#007D34', '#803E75', '#FF6800',
#           '#817066', '#FFB300', '#F67

# %% [markdown]
# ## Here we load the first article in the sci.crypt directory

# %%
The first document in this directory will now be analyzed.  What topics will our model predict are most prevalent in this document?

# %%
val test_input = Seq(Source.fromFile("20_newsgroups/sci.crypt/14147").getLines.reduce(_+_))

println("trying to assign a topic to the following text")

println("===")
println(test_input)
println("===")
# Out:
# trying to assign a topic to the following text
# ===
# List(Xref: cantaloupe.srv.cs.cmu.edu alt.security.ripem:136 sci.crypt:14147 comp.security.misc:2868 alt.security:9389 comp.mail.misc:11904 comp.answers:213 news.answers:6521Newsgroups: alt.security.ripem,sci.crypt,comp.security.misc,alt.security,comp.mail.misc,comp.answers,news.answersPath: cantaloupe.srv.cs.cmu.edu!crabapple.srv.cs.cmu.edu!fs7.ece.cmu.edu!news.sei.cmu.edu!cis.ohio-state.edu!zaphod.mps.ohio-state.edu!wupost!spool.mu.edu!caen!sol.ctr.columbia.edu!usenet.ucs.indiana.edu!silver.ucs.indiana.edu!mvanheynFrom: Marc VanHeyningen <mvanheyn@cs.indiana.edu>Subject: RIPEM Frequently Asked QuestionsContent-Type: text/x-usenet-FAQ; version=1.0; title="RIPEM FAQ"Message-ID: <C3Juww.Dru@usenet.ucs.indiana.edu>Followup-To: alt.security.ripemOriginator: mvanheyn@silver.ucs.indiana.eduSender: news@usenet.ucs.indiana.edu (USENET News System)Supersedes: <1993Jan25.113427.28926@news.cs.indiana.edu>Nntp-Posting-Host: silver.ucs.indiana.eduOrganization: Computer Science, Indiana UniversityDate: Mon, 8 Mar 1993 02:58:07 GMTApproved: news-answers-request@MIT.EDUExpires: Fri, 30 Apr 1993 00:00:00 GMTLines: 255Archive-name: ripem/faqLast-update: Sun, 7 Mar 93 21:00:00 -0500ABOUT THIS POSTING------------------This is a (still rather rough) listing of likely questions andinformation about RIPEM, a program for public key mail encryption.  It(this FAQ, not RIPEM) was written and will be maintained by MarcVanHeyningen, <mvanheyn@whale.cs.indiana.edu>.  It will be posted to avariety of newsgroups on a monthly basis; follow-up discussion specificto RIPEM is redirected to the group alt.security.ripem.This month, I have reformatted this posting in an attempt to complywith the standards for HyperText FAQ formatting to allow easymanipulation of this document over the World Wide Web.  Let me knowwhat you think.DISCLAIMER----------Nothing in this FAQ should be considered legal advice, or anythingother than one person's opinion.  If you want real legal advice, talkto a real lawyer.QUESTIONS AND ANSWERS---------------------1)  What is RIPEM? RIPEM is a program which performs Privacy Enhanced Mail (PEM) using the cryptographic techniques of RSA and DES.  It allows your electronic mail to have the properties of authentication (i.e. who sent it can be confirmed) and privacy (i.e. nobody can read it except the intended recipient.) RIPEM was written primarily by Mark Riordan <mrr@scss3.cl.msu.edu>. Most of the code is in the public domain, except for the RSA routines, which are a library called RSAREF licensed from RSA Data Security Inc.2)  How can I get RIPEM? RIPEM contains the library of cryptographic routines RSAREF, which is considered munitions and thus is export-restricted from distribution to people who are not citizens or permanent residents of the U.S. or Canada.  Therefore, the following request is quoted from the README file: #Please do not export the cryptographic code in this distribution #outside of the USA or Canada.  This is a personal request from me, #the author of RIPEM, and a condition of your use of RIPEM. Note that RSAREF is not in the public domain, and a license for it is included with the distribution.  You should read it before using RIPEM. The best way to get it is to ask a friend for a copy, since this will reduce the load on those sites that do carry it (not to mention the humans that run them.)  Naturally this requires that you trust the friend. RIPEM is available via anonymous FTP to citizens and permanent residents in the U.S. from rsa.com; cd to rsaref/ and read the README file for info.  Last I looked, this site contains only the source tree, and does not contain compiled binaries or the nice Mac version. RIPEM, as well as some other crypt stuff, has its "home site" on rpub.cl.msu.edu, which is open to non-anonymous FTP for users in the U.S. and Canada who are citizens or permanent residents.  To find out how to obtain access, ftp there, cd to pub/crypt/, and read the file GETTING_ACCESS.  For convenience, binaries for ma ...
# ===
# test_input = List(Xref: cantaloupe.srv.cs.cmu.edu alt.security.ripem:136 sci.crypt:14147 comp.security.misc:2868 alt.security:9389 comp.mail.misc:11904 comp.answers:213 news.answers:6521Newsgroups: alt.security.ripem,sci.crypt,comp.security.misc,alt.security,comp.mail.misc,comp.answers,news.answersPath: cantaloupe.srv.cs.cmu.edu!crabapple.srv.cs.cmu.edu!fs7.ece.cmu.edu!news.sei.cmu.edu!cis.ohio-state.edu!zaphod.mps.ohio-state.edu!wupost!spool.mu.edu!caen!sol.ctr.columbia.edu!usenet.ucs.indiana.edu!silver.ucs.indiana.edu!mvanheynFrom: Marc VanHeyningen <mvanheyn@cs.indiana.edu>Subject: RIPEM Frequently Asked QuestionsContent-Type: text/x-usenet-FAQ; version=1.0; title="RIPEM FAQ"Message-ID: <C3Juww.Dru@usenet.ucs.indiana.edu>Followup-To: alt.security.ripemOriginator: mvanhey...
# List(Xref: cantaloupe.srv.cs.cmu.edu alt.security.ripem:136 sci.crypt:14147 comp.security.misc:2868 alt.security:9389 comp.mail.misc:11904 comp.answers:213 news.answers:6521Newsgroups: alt.security.ripem,sci.crypt,comp.security.misc,alt.security,comp.mail.misc,comp.answers,news.answersPath: cantaloupe.srv.cs.cmu.edu!crabapple.srv.cs.cmu.edu!fs7.ece.cmu.edu!news.sei.cmu.edu!cis.ohio-state.edu!zaphod.mps.ohio-state.edu!wupost!spool.mu.edu!caen!sol.ctr.columbia.edu!usenet.ucs.indiana.edu!silver.ucs.indiana.edu!mvanheynFrom: Marc VanHeyningen <mvanheyn@cs.indiana.edu>Subject: RIPEM Frequently Asked QuestionsContent-Type: text/x-usenet-FAQ; version=1.0; title="RIPEM FAQ"Message-ID: <C3Juww.Dru@usenet.ucs.indiana.edu>Followup-To: alt.security.ripemOriginator: mvanheyn@silver.ucs.indiana.eduSender: news@usenet.ucs.indiana.edu (USENET News System)Supersedes: <1993Jan25.113427.28926@news.cs.indiana.edu>Nntp-Posting-Host: silver.ucs.indiana.eduOrganization: Computer Science, Indiana UniversityDate: Mon, 8 Mar 1993 02:58:07 GMTApproved: news-answers-request@MIT.EDUExpires: Fri, 30 Apr 1993 00:00:00 GMTLines: 255Archive-name: ripem/faqLast-update: Sun, 7 Mar 93 21:00:00 -0500ABOUT THIS POSTING------------------This is a (still rather rough) listing of likely questions andinformation about RIPEM, a program for public key mail encryption.  It(this FAQ, not RIPEM) was written and will be maintained by MarcVanHeyningen, <mvanheyn@whale.cs.indiana.edu>.  It will be posted to avariety of newsgroups on a monthly basis; follow-up discussion specificto RIPEM is redirected to the group alt.security.ripem.This month, I have reformatted this posting in an attempt to complywith the standards for HyperText FAQ formatting to allow easymanipulation of this document over the World Wide Web.  Let me knowwhat you think.DISCLAIMER----------Nothing in this FAQ should be considered legal advice, or anythingother than one person's opinion.  If you want real legal advice, talkto a real lawyer.QUESTIONS AND ANSWERS---------------------1)  What is RIPEM? RIPEM is a program which performs Privacy Enhanced Mail (PEM) using the cryptographic techniques of RSA and DES.  It allows your electronic mail to have the properties of authentication (i.e. who sent it can be confirmed) and privacy (i.e. nobody can read it except the intended recipient.) RIPEM was written primarily by Mark Riordan <mrr@scss3.cl.msu.edu>. Most of the code is in the public domain, except for the RSA routines, which are a library called RSAREF licensed from RSA Data Security Inc.2)  How can I get RIPEM? RIPEM contains the library of cryptographic routines RSAREF, which is considered munitions and thus is export-restricted from distribution to people who are not citizens or permanent residents of the U.S. or Canada.  Therefore, the following request is quoted from the README file: #Please do not export the cryptographic code in this distribution #outside of the USA or Canada.  This is a personal request from me, #the author of RIPEM, and a condition of your use of RIPEM. Note that RSAREF is not in the public domain, and a license for it is included with the distribution.  You should read it before using RIPEM. The best way to get it is to ask a friend for a copy, since this will reduce the load on those sites that do carry it (not to mention the humans that run them.)  Naturally this requires that you trust the friend. RIPEM is available via anonymous FTP to citizens and permanent residents in the U.S. from rsa.com; cd to rsaref/ and read the README file for info.  Last I looked, this site contains only the source tree, and does not contain compiled binaries or the nice Mac version. RIPEM, as well as some other crypt stuff, has its "home site" on rpub.cl.msu.edu, which is open to non-anonymous FTP for users in the U.S. and Canada who are citizens or permanent residents.  To find out how to obtain access, ftp there, cd to pub/crypt/, and read the file GETTING_ACCESS.  For convenience, binaries for ma ...

# %% [markdown]
# ## Generating a Topic Distribution from the text document

# %% [markdown]
# - TODO:  Add the equations for topic distributions?
#
# Here we generate the estimate of the fraction of each topic present in this set of words.  The topic that is most strongly represented here would be considered the main subject of the article.

# %%
val test_document = sc.parallelize(test_input.map(doc=>doc.split("\\s")).zipWithIndex.map{ case (tokens, id) =>
    val counts = new mutable.HashMap[Int, Double]()
    tokens.foreach { term =>
    if (vocabLoaded.contains(term)) {
        val idx = vocabLoaded(term)
        counts(idx) = counts.getOrElse(idx, 0.0) + 1.0
        }
    }
    (id.toLong, Vectors.sparse(vocabLoaded.size, counts.toSeq))
})


val localLDAModelLoaded: LocalLDAModel = ldaModelLoaded.asInstanceOf[DistributedLDAModel].toLocal
val topicDistributions = localLDAModelLoaded.topicDistributions(test_document)
println("first topic distribution:" + topicDistributions.first._2.toArray.mkString(", "))
# Out:
# first topic distribution:0.3678651688357385, 0.16033980860948344, 0.030735811366463403, 0.05206532087578698, 0.05230728554300706, 0.06665422319327728, 0.04200850832933759, 0.06093942907232035, 0.06837865937763134, 0.09870578479695413
# test_document = ParallelCollectionRDD[92] at parallelize at <console>:50
# localLDAModelLoaded = org.apache.spark.mllib.clustering.LocalLDAModel@6e48e008
# topicDistributions = MapPartitionsRDD[93] at map at LDAModel.scala:356
# MapPartitionsRDD[93] at map at LDAModel.scala:356

# %%
val localLDAModelLoaded: LocalLDAModel = ldaModelLoaded.asInstanceOf[DistributedLDAModel].toLocal
val topicDistributions = localLDAModelLoaded.topicDistributions(test_document)
println("first topic distribution:" + topicDistributions.first._2.toArray.mkString(", "))
# Out:
# first topic distribution:0.36786523297221063, 0.16033828435894748, 0.030735711602361673, 0.05206433589847484, 0.0523069847727492, 0.06665434863907264, 0.04200754078034929, 0.06094140495115028, 0.06837956418138692, 0.09870659184329698
# localLDAModelLoaded = org.apache.spark.mllib.clustering.LocalLDAModel@3f1b4c04
# topicDistributions = MapPartitionsRDD[91] at map at LDAModel.scala:356
# MapPartitionsRDD[91] at map at LDAModel.scala:356

# %% [markdown]
# ## Displaying Topic Distributions

# %% [markdown]
# - By looking at the table and bar plot, we can see that this article is strongly associated with topic 6.  This seems to match our understanding of the nature of topic 6 based on our review of the word cloud for this topic.

# %%
val topicDistributionsDF = sc.parallelize(topicDistributions.map(x=>x._2).first.toArray.zipWithIndex).
                         toDF("TopicFraction","TopicNumber")
topicDistributionsDF.show
# Out:
# +--------------------+-----------+
# |       TopicFraction|TopicNumber|
# +--------------------+-----------+
# |  0.3678649762344198|          0|
# | 0.16033806996173225|          1|
# |0.030735693886702244|          2|
# | 0.05206535944793738|          3|
# | 0.05230728788829701|          4|
# | 0.06665456846835575|          5|
# |   0.042005077688621|          6|
# |0.060942125531264255|          7|
# | 0.06838005368148471|          8|
# | 0.09870678721118552|          9|
# +--------------------+-----------+
# topicDistributionsDF = [TopicFraction: double, TopicNumber: int]
# [TopicFraction: double, TopicNumber: int]

# %%
# %%brunel data('topicDistributionsDF') bar x(TopicNumber) y(TopicFraction) transpose
# Out:
#                 'brunel' : 'https://brunelvis.org/js...
#          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/brunel.2.5.css" charset="utf-8">
#          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/sumoselect.css" charset="utf-8">
#          <style>  </style>
#          <div id="controlsId0bf781e8-81f2-4fab-95ae-6387bb03863e" class="brunel"/>
# <svg id="visidf33a8175-b7b4-48ed-8369-c0368b2cc96c" width="500" height="400"></svg>
#
# <script>
# require.config({
#             waitSeconds: 60,
#             paths: {
#                 'd3': '//cdnjs.cloudflare.com/ajax/libs/d3/4.2.1/d3.min',
#                 'topojson' : '//cdnjs.cloudflare.com/ajax/libs/topojson/1.6.20/topojson.min',
#                 'brunel' : 'https://brunelvis.org/js/brunel.2.5.min',
#                 'brunelControls' : 'https://brunelvis.org/js/brunel.controls.2.5.min'
#             },
#
#             shim: {
#                'brunel' : {
#                     exports: 'BrunelD3',
#                     deps: ['d3', 'topojson'],
#                     init: function() {
#                        return {
#                          BrunelD3 : BrunelD3,
#                          BrunelData : BrunelData
#                       }
#                     }
#                 },
#                'brunelControls' : {
#                     exports: 'BrunelEventHandlers',
#                     init: function() {
#                        return {
#                          BrunelEventHandlers: BrunelEventHandlers,
#                          BrunelJQueryControlFactory: BrunelJQueryControlFactory
#                       }
#                     }
#                 }
#
#             }
#
#         });
#
#         require(["d3"], function(d3) {
#         require(["brunel", "brunelControls"], function(brunel, brunelControls) {
#
#             function  BrunelVis(visId) {
#   "use strict";                                                                       // strict mode
#   var datasets = [],                                      // array of datasets for the original data
#       pre = function(d, i) { return d },                         // default pre-process does nothing
#       post = function(d, i) { return d },                       // default post-process does nothing
#       transitionTime = 200,                                        // transition time for animations
#       charts = [],                                                       // the charts in the system
#       vis = d3.select('#' + visId).attr('class', 'brunel');                     // the SVG container
#
#   BrunelD3.addDefinitions(vis);                                   // ensure standard symbols present
#
#   // Define chart #1 in the visualization //////////////////////////////////////////////////////////
#
#   charts[0] = function(parentNode, filterRows) {
#     var geom = BrunelD3.geometry(parentNode || vis.node(), 0, 0, 1, 1, 5, 47, 37, 15),
#       elements = [];                                              // array of elements in this chart
#     geom.transpose();
#
#     // Define groups for the chart parts ///////////////////////////////////////////////////////////
#
#     var chart =  vis.append('g').attr('class', 'chart1')
#       .attr('transform','translate(' + geom.chart_left + ',' + geom.chart_top + ')');
#     var overlay = chart.append('g').attr('class', 'element').attr('class', 'overlay');
#     var zoom = d3.zoom().scaleExtent([1/3,3]);
#     var zoomNode = overlay.append('rect').attr('class', 'overlay')
#       .attr('x', geom.inner_left).attr('y', geom.inner_top)
#       .attr('width', geom.inner_rawWidth).attr('height', geom.inner_rawHeight)
#       .style('cursor', 'move').call(zoom)
#       .node();
#     zoomNode.__zoom = d3.zoomIdentity;
#     chart.append('rect').attr('class', 'background').attr('width', geom.chart_right-geom.chart_left).attr('height', geom.chart_bottom-geom.chart_top);
#     var interior = chart.append('g').attr('class', 'interior zoomNone')
#       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')')
#       .attr('clip-path', 'url(#clip_visidf33a8175-b7b4-48ed-8369-c0368b2cc96c_chart1_inner)');
#     interior.append('rect').attr('class', 'inner').attr('width', geom.inner_width).attr('height', geom.inner_height);
#     var gridGroup = interior.append('g').attr('class', 'grid');
#     var axes = chart.append('g').attr('class', 'axis')
#       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')');
#     vis.select('defs').append('clipPath').attr('id', 'clip_visidf33a8175-b7b4-48ed-8369-c0368b2cc96c_chart1_inner').append('rect')
#       .attr('x', 0).attr('y', 0)
#       .attr('width', geom.inner_rawWidth+1).attr('height', geom.inner_rawHeight+1);
#
#     // Scales //////////////////////////////////////////////////////////////////////////////////////
#
#     var scale_x = d3.scaleLinear().domain([-2, 10.000001])
#       .range([geom.inner_width, 0]);
#     var scale_inner = d3.scaleLinear().domain([0,1])
#       .range([-0.5, 0.5]);
#     var scale_y = d3.scaleSqrt().domain([0, 0.4])
#       .range([0, geom.inner_height]);
#     var base_scales = [scale_x, scale_y];                           // untransformed original scales
#
#     // Axes ////////////////////////////////////////////////////////////////////////////////////////
#
#     axes.append('g').attr('class', 'x axis')
#       .attr('transform','translate(0,' + geom.inner_rawHeight + ')')
#       .attr('clip-path', 'url(#clip_visidf33a8175-b7b4-48ed-8369-c0368b2cc96c_chart1_haxis)');
#     vis.select('defs').append('clipPath').attr('id', 'clip_visidf33a8175-b7b4-48ed-8369-c0368b2cc96c_chart1_haxis').append('polyline')
#       .attr('points', '-1,-1000, -1,-1 -5,5, -1000,5, -100,1000, 10000,1000 10000,-1000');
#     axes.select('g.axis.x').append('text').attr('class', 'title').text('TopicFraction').style('text-anchor', 'middle')
#       .attr('x',geom.inner_rawWidth/2)
#       .attr('y', geom.inner_bottom - 2.0).attr('dy','-0.27em');
#     axes.append('g').attr('class', 'y axis')
#       .attr('clip-path', 'url(#clip_visidf33a8175-b7b4-48ed-8369-c0368b2cc96c_chart1_vaxis)');
#     vis.select('defs').append('clipPath').attr('id', 'clip_visidf33a8175-b7b4-48ed-8369-c0368b2cc96c_chart1_vaxis').append('polyline')
#       .attr('points', '-1000,-10000, 10000,-10000, 10000,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+5) + ', -1000,' + (geom.inner_rawHeight+5) );
#     axes.select('g.axis.y').append('text').attr('class', 'title').text('TopicNumber').style('text-anchor', 'middle')
#       .attr('x',-geom.inner_rawHeight/2)
#       .attr('y', 4-geom.inner_left).attr('dy', '0.7em').attr('transform', 'rotate(270)');
#
#     var axis_bottom = d3.axisBottom(scale_y).ticks(Math.min(10, Math.round(geom.inner_rawWidth / 39.0)));
#     var axis_left = d3.axisLeft(scale_x).ticks(Math.min(10, Math.round(geom.inner_rawHeight / 20)));
#
#     function buildAxes(time) {
#       var axis_x = axes.select('g.axis.x');
#       BrunelD3.transition(axis_x, time).call(axis_bottom.scale(scale_y));
#       var axis_y = axes.select('g.axis.y');
#       BrunelD3.transition(axis_y, time).call(axis_left.scale(scale_x));
#     }
#     zoom.on('zoom', function(t, time) {
#         t = t ||BrunelD3.restrictZoom(d3.event.transform, geom, this);
#         scale_x = t.rescaleY(base_scales[0]);
#         scale_y = t.rescaleX(base_scales[1]);
#         zoomNode.__zoom = t;
#         interior.attr('class', 'interior ' + BrunelD3.zoomLabel(t.k));;
#         build(time || -1);
#     });
#
#     // Define element #1 ///////////////////////////////////////////////////////////////////////////
#
#     elements[0] = function() {
#       var original, processed,                           // data sets passed in and then transformed
#         element, data,                                 // brunel element information and brunel data
#         selection, merged;                                      // d3 selection and merged selection
#       var elementGroup = interior.append('g').attr('class', 'element1')
#         .attr('transform','matrix(0,1,1,0,0,0)'),
#         main = elementGroup.append('g').attr('class', 'main'),
#         labels
